# %% [markdown]
# Đọc tập dữ liệu

# %%
# prompt:  đọc tập dữ liệu Mushroom Dataset từ UCI Machine Learning Repository

import pandas as pd

# Đường dẫn đến tập dữ liệu Mushroom Dataset trên UCI Machine Learning Repository
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data"

# Đọc tập dữ liệu vào DataFrame
column_names = ["class", "cap-shape", "cap-surface", "cap-color", "bruises", "odor", "gill-attachment", "gill-spacing", "gill-size", "gill-color", "stalk-shape", "stalk-root", "stalk-surface-above-ring", "stalk-surface-below-ring", "stalk-color-above-ring", "stalk-color-below-ring", "veil-type", "veil-color", "ring-number", "ring-type", "spore-print-color", "population", "habitat"]
df = pd.read_csv(url, names=column_names)

# In ra một số dòng đầu tiên của DataFrame để kiểm tra
print(df.head())
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# Biểu đồ cho cap-shape (Hình dạng mũ nấm):
#
# b: bell (hình chuông)
# c: conical (hình nón)
# x: convex (lồi)
# f: flat (phẳng)
# k: knobbed (nút)
# s: sunken (lõm)

# %%
# prompt: cap-shape (Hình dạng mũ nấm):
# b: bell (hình chuông)
# c: conical (hình nón)
# x: convex (lồi)
# f: flat (phẳng)
# k: knobbed (nút)
# s: sunken (lõm)
# vẽ biểu đồ

import matplotlib.pyplot as plt

# Đếm số lượng mỗi loại cap-shape
cap_shape_counts = df['cap-shape'].value_counts()

# Vẽ biểu đồ
plt.figure(figsize=(8, 6))
bars = plt.bar(cap_shape_counts.index, cap_shape_counts.values)
plt.xlabel('Cap Shape')
plt.ylabel('Count')
plt.title('Distribution of Cap Shape Components')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# cap-surface (Bề mặt mũ nấm):
#
# f: fibrous (sợi)
# g: grooves (rãnh)
# y: scaly (vảy)
# s: smooth (trơn)

# %%
# prompt: vẽ biểu đồ cho
# cap-surface (Bề mặt mũ nấm):
# có thêm số trên mỗi đỉnh cột
# f: fibrous (sợi)
# g: grooves (rãnh)
# y: scaly (vảy)
# s: smooth (trơn)

import pandas as pd
import matplotlib.pyplot as plt

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho cap-surface (Bề mặt mũ nấm)
cap_surface_counts = df['cap-surface'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(cap_surface_counts.index, cap_surface_counts.values)
plt.xlabel('Cap Surface')
plt.ylabel('Count')
plt.title('Distribution of Cap Surface Components')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# cap-color (Màu sắc mũ nấm):
#
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# r: green (xanh lá)
# p: pink (hồng)
# u: purple (tím)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)

# %%
# prompt: cap-color (Màu sắc mũ nấm):
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# r: green (xanh lá)
# p: pink (hồng)
# u: purple (tím)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)
# vẽ biểu đồ, có thêm số trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho cap-color (Màu sắc mũ nấm)
cap_color_counts = df['cap-color'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(cap_color_counts.index, cap_color_counts.values)
plt.xlabel('Cap Color')
plt.ylabel('Count')
plt.title('Distribution of Cap Color')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# bruises (Vết bầm):
#
# t: bruises (có bầm tím)
# f: no bruises (không có bầm tím)

# %%
# prompt: bruises (Vết bầm):
# t: bruises (có bầm tím)
# f: no bruises (không có bầm tím)
# vẽ biểu đồ, có số trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho bruises (Vết bầm)
bruises_counts = df['bruises'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(bruises_counts.index, bruises_counts.values)
plt.xlabel('Bruises')
plt.ylabel('Count')
plt.title('Distribution of Bruises')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# odor (Mùi):
#
# a: almond (hạnh nhân)
# l: anise (hoa hồi)
# c: creosote (nhựa)
# y: fishy (mùi cá)
# f: foul (thối)
# m: musty (ẩm mốc)
# n: none (không mùi)
# p: pungent (hăng)
# s: spicy (cay)

# %%
# prompt: odor (Mùi):
# a: almond (hạnh nhân)
# l: anise (hoa hồi)
# c: creosote (nhựa)
# y: fishy (mùi cá)
# f: foul (thối)
# m: musty (ẩm mốc)
# n: none (không mùi)
# p: pungent (hăng)
# s: spicy (cay)
# vẽ biểu đồ có thêm số trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho odor (Mùi)
odor_counts = df['odor'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(odor_counts.index, odor_counts.values)
plt.xlabel('Odor')
plt.ylabel('Count')
plt.title('Distribution of Odor')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# gill-attachment (Gân dưới mũ nấm):
#
# a: attached (gắn)
# d: descending (chảy xuống)
# f: free (tách rời)
# n: notched (có khía)

# %%
# prompt: gill-attachment (Gân dưới mũ nấm):
# a: attached (gắn)
# d: descending (chảy xuống)
# f: free (tách rời)
# n: notched (có khía)
# vẽ biểu đồ có thêm số lượng trên mỗi cột, có đầy đủ thuộc tính

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho gill-attachment (Gân dưới mũ nấm)
gill_attachment_counts = df['gill-attachment'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(gill_attachment_counts.index, gill_attachment_counts.values)
plt.xlabel('Gill Attachment')
plt.ylabel('Count')
plt.title('Distribution of Gill Attachment')

# Thêm chú thích cho từng loại gill-attachment
plt.xticks([0, 1, 2, 3], ['Attached (a)', 'Descending (d)', 'Free (f)', 'Notched (n)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# gill-spacing (Khoảng cách gân):
#
# c: close (gần)
# w: crowded (chen chúc)
# d: distant (xa)

# %%
# prompt: gill-spacing (Khoảng cách gân):
# c: close (gần)
# w: crowded (chen chúc)
# d: distant (xa)
# vẽ biểu đồ, có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho gill-spacing (Khoảng cách gân)
gill_spacing_counts = df['gill-spacing'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(gill_spacing_counts.index, gill_spacing_counts.values)
plt.xlabel('Gill Spacing')
plt.ylabel('Count')
plt.title('Distribution of Gill Spacing')

# Thêm chú thích cho từng loại gill-spacing
plt.xticks([0, 1, 2], ['Close (c)', 'Crowded (w)', 'Distant (d)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# gill-size (Kích thước gân):
#
# b: broad (rộng)
# n: narrow (hẹp)

# %%
# prompt: gill-size (Kích thước gân):
# b: broad (rộng)
# n: narrow (hẹp) vẽ biểu đồ

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho gill-size (Kích thước gân)
gill_size_counts = df['gill-size'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(gill_size_counts.index, gill_size_counts.values)
plt.xlabel('Gill Size')
plt.ylabel('Count')
plt.title('Distribution of Gill Size')

# Thêm chú thích cho từng loại gill-size
plt.xticks([0, 1], ['Broad (b)', 'Narrow (n)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# gill-color (Màu sắc gân):
#
# k: black (đen)
# n: brown (nâu)
# b: buff (nâu sáng)
# h: chocolate (sô cô la)
# g: gray (xám)
# r: green (xanh lá)
# o: orange (cam)
# p: pink (hồng)
# u: purple (tím)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)

# %%
# prompt: gill-color (Màu sắc gân):
# k: black (đen)
# n: brown (nâu)
# b: buff (nâu sáng)
# h: chocolate (sô cô la)
# g: gray (xám)
# r: green (xanh lá)
# o: orange (cam)
# p: pink (hồng)
# u: purple (tím)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)
# vẽ biểu đồ, có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho gill-color (Màu sắc gân)
gill_color_counts = df['gill-color'].value_counts()

plt.figure(figsize=(12, 6))
bars = plt.bar(gill_color_counts.index, gill_color_counts.values)
plt.xlabel('Gill Color')
plt.ylabel('Count')
plt.title('Distribution of Gill Color Components')

# Thêm chú thích cho từng loại gill-color
# (Bạn có thể thêm chú thích chi tiết cho từng loại màu sắc nếu cần)

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# stalk-shape (Hình dạng thân nấm):
#
# e: enlarging (phình to về phía gốc)
# t: tapering (thon nhỏ về phía gốc)

# %%
# prompt: stalk-shape (Hình dạng thân nấm):
# e: enlarging (phình to về phía gốc)
# t: tapering (thon nhỏ về phía gốc)
# vẽ biểu đồ

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-shape (Hình dạng thân nấm)
stalk_shape_counts = df['stalk-shape'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(stalk_shape_counts.index, stalk_shape_counts.values)
plt.xlabel('Stalk Shape')
plt.ylabel('Count')
plt.title('Distribution of Stalk Shape')

# Thêm chú thích cho từng loại stalk-shape
plt.xticks([0, 1], ['Enlarging (e)', 'Tapering (t)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# stalk-root (Gốc thân nấm):
#
# b: bulbous (phình to)
# c: club (hình dùi)
# u: cup (cốc)
# e: equal (đều)
# z: rhizomorphs (rễ hình sợi)
# r: rooted (có rễ)
# ?: missing (thiếu)

# %%
# prompt: stalk-root (Gốc thân nấm):
# b: bulbous (phình to)
# c: club (hình dùi)
# u: cup (cốc)
# e: equal (đều)
# z: rhizomorphs (rễ hình sợi)
# r: rooted (có rễ)
# ?: missing (thiếu)
# Vẽ biểu đồ, có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-root (Gốc thân nấm)
stalk_root_counts = df['stalk-root'].value_counts()
print(df['stalk-root'].unique())

plt.figure(figsize=(8, 6))
bars = plt.bar(stalk_root_counts.index, stalk_root_counts.values)
plt.xlabel('Stalk Root')
plt.ylabel('Count')
plt.title('Distribution of Stalk Root Components')


# Thêm chú thích cho từng loại stalk-root
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7], ['b', '?', 'e', 'c', 'r', 'z', 'u', ' '])
print(bars)

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()
# Out:
# ['e' 'c' 'b' 'r' '?']
# <BarContainer object of 5 artists>

# %% [markdown]
# stalk-surface-above-ring (Bề mặt thân nấm trên vòng):
#
# f: fibrous (sợi)
# y: scaly (vảy)
# k: silky (lụa)
# s: smooth (trơn)

# %%
# prompt: stalk-surface-above-ring (Bề mặt thân nấm trên vòng):
# f: fibrous (sợi)
# y: scaly (vảy)
# k: silky (lụa)
# s: smooth (trơn)
# vẽ biểu đồ, có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-surface-above-ring (Bề mặt thân nấm trên vòng)
stalk_surface_above_ring_counts = df['stalk-surface-above-ring'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(stalk_surface_above_ring_counts.index, stalk_surface_above_ring_counts.values)
plt.xlabel('Stalk Surface Above Ring')
plt.ylabel('Count')
plt.title('Distribution of Stalk Surface Above Ring')

# Thêm chú thích cho từng loại stalk-surface-above-ring
plt.xticks([0, 1, 2, 3], ['Fibrous (f)', 'Scaly (y)', 'Silky (k)', 'Smooth (s)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# stalk-surface-below-ring (Bề mặt thân nấm dưới vòng):
#
# f: fibrous (sợi)
# y: scaly (vảy)
# k: silky (lụa)
# s: smooth (trơn)

# %%
# prompt: stalk-surface-below-ring (Bề mặt thân nấm dưới vòng):
# f: fibrous (sợi)
# y: scaly (vảy)
# k: silky (lụa)
# s: smooth (trơn)
# vẽ biểu đồ, có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-surface-below-ring (Bề mặt thân nấm dưới vòng)
stalk_surface_below_ring_counts = df['stalk-surface-below-ring'].value_counts()

plt.figure(figsize=(8, 6))
bars = plt.bar(stalk_surface_below_ring_counts.index, stalk_surface_below_ring_counts.values)
plt.xlabel('Stalk Surface Below Ring')
plt.ylabel('Count')
plt.title('Distribution of Stalk Surface Below Ring')

# Thêm chú thích cho từng loại stalk-surface-below-ring
plt.xticks([0, 1, 2, 3], ['Fibrous (f)', 'Scaly (y)', 'Silky (k)', 'Smooth (s)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# stalk-color-above-ring (Màu thân nấm trên vòng):
#
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# o: orange (cam)
# p: pink (hồng)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)

# %%
# prompt: stalk-color-above-ring (Màu thân nấm trên vòng):
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# o: orange (cam)
# p: pink (hồng)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)
# vẽ biểu đồ có thông số trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-color-above-ring (Màu thân nấm trên vòng)
stalk_color_above_ring_counts = df['stalk-color-above-ring'].value_counts()

plt.figure(figsize=(12, 6))
bars = plt.bar(stalk_color_above_ring_counts.index, stalk_color_above_ring_counts.values)
plt.xlabel('Stalk Color Above Ring')
plt.ylabel('Count')
plt.title('Distribution of Stalk Color Above Ring')

# Thêm chú thích cho từng loại stalk-color-above-ring
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['Brown (n)', 'Buff (b)', 'Cinnamon (c)', 'Gray (g)', 'Orange (o)', 'Pink (p)', 'Red (e)', 'White (w)', 'Yellow (y)'])

# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %% [markdown]
# stalk-color-below-ring (Màu thân nấm dưới vòng):
#
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# o: orange (cam)
# p: pink (hồng)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)

# %%
# prompt: vẽ biểu đồ
# stalk-color-below-ring (Màu thân nấm dưới vòng):
# n: brown (nâu)
# b: buff (nâu sáng)
# c: cinnamon (quế)
# g: gray (xám)
# o: orange (cam)
# p: pink (hồng)
# e: red (đỏ)
# w: white (trắng)
# y: yellow (vàng)
# có số lượng trên mỗi cột

# ... (phần code đọc dữ liệu từ trước) ...

# Biểu đồ cho stalk-color-below-ring (Màu thân nấm dưới vòng)
stalk_color_below_ring_counts = df['stalk-color-below-ring'].value_counts()

plt.figure(figsize=(12, 6))
bars = plt.bar(stalk_color_below_ring_counts.index, stalk_color_below_ring_counts.values)
plt.xlabel('Stalk Color Below Ring')
plt.ylabel('Count')
plt.title('Distribution of Stalk Color Below Ring')

# Thêm chú thích cho từng loại stalk-color-below-ring
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['Brown (n)', 'Buff (b)', 'Cinnamon (c)', 'Gray (g)', 'Orange (o)', 'Pink (p)', 'Red (e)', 'White (w)', 'Yellow (y)'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %%
stalk_color_below_ring_counts = df['veil-type'].value_counts()

plt.figure(figsize=(12, 6))
bars = plt.bar(stalk_color_below_ring_counts.index, stalk_color_below_ring_counts.values)
plt.xlabel('Veil Type')
plt.ylabel('Count')
plt.title('Distribution of Veil Type Components')

# Thêm chú thích cho từng loại stalk-color-below-ring
plt.xticks([0, 1], ['p', 'u'])


# Thêm số lượng lên trên mỗi cột
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/3, yval + 0.5, yval, ha='center', va='bottom')

plt.show()

# %%
# Đếm số lượng từng loại trong cột 'veil-type'
stalk_color_below_ring_counts = df['veil-type'].value_counts()

plt.figure(figsize=(12, 6))

# Vẽ biểu đồ cột
bars = plt.bar(stalk_color_below_ring_counts.index, stalk_color_below_ring_counts.values)
plt.xlabel('Veil Type')
plt.ylabel('Count')
plt.title('Distribution of Veil Type Components')

# Đặt nhãn cho trục x với canh giữa
plt.xticks(range(len(stalk_color_below_ring_counts.index)+2), ['p', 'u', ' '], ha='center')

# Thêm số lượng lên trên mỗi cột
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.5, int(yval), ha='center', va='bottom')

plt.show()
